# %% [markdown]
# # Import file

# %%
# import library

import math
import pysal as ps
import numpy as np
import pandas as pd
import seaborn as sns
import geopandas as gpd
import matplotlib.pyplot as plt
import plotly.express as px

from shapely.geometry import Point, Polygon

from math import ceil

from sklearn.neighbors import NearestNeighbors
from sklearn.cluster import KMeans, DBSCAN, OPTICS, AgglomerativeClustering
from esda.adbscan import ADBSCAN
from sklearn import metrics
from sklearn.preprocessing import RobustScaler, MinMaxScaler

from scipy.cluster.hierarchy import dendrogram

import spopt
from spopt.region import MaxPHeuristic as MaxP
import matplotlib.pyplot as plt

import libpysal
import warnings

# %% [markdown]
# # bikin list nama kota

# %%
# Make an array of all the city name
city_name = ["Bangkalan", "Banyuwangi", "Batu", "Blitar", "Bojonegoro", "Bondowoso", "Gresik", "Jember", "Jombang", "Kediri", "Kota_Blitar", "Kota_Kediri", "Kota_Madiun", "Kota_Malang", "Kota_Mojokerto", "Kota_Pasuruan", "Kota_Probolinggo", "Lamongan", "Lumajang", "Madiun", "Magetan", "Malang", "Mojokerto", "Nganjuk", "Ngawi", "Pacitan", "Pamekasan", "Pasuruan", "Ponorogo", "Probolinggo", "Sampang", "Sidoarjo", "Situbondo", "Sumenep", "Surabaya", "Trenggalek", "Tuban", "Tulungagung"]

city_name
# Out:
# ['Bangkalan',
#  'Banyuwangi',
#  'Batu',
#  'Blitar',
#  'Bojonegoro',
#  'Bondowoso',
#  'Gresik',
#  'Jember',
#  'Jombang',
#  'Kediri',
#  'Kota_Blitar',
#  'Kota_Kediri',
#  'Kota_Madiun',
#  'Kota_Malang',
#  'Kota_Mojokerto',
#  'Kota_Pasuruan',
#  'Kota_Probolinggo',
#  'Lamongan',
#  'Lumajang',
#  'Madiun',
#  'Magetan',
#  'Malang',
#  'Mojokerto',
#  'Nganjuk',
#  'Ngawi',
#  'Pacitan',
#  'Pamekasan',
#  'Pasuruan',
#  'Ponorogo',
#  'Probolinggo',
#  'Sampang',
#  'Sidoarjo',
#  'Situbondo',
#  'Sumenep',
#  'Surabaya',
#  'Trenggalek',
#  'Tuban',
#  'Tulungagung']

# %% [markdown]
# ### Trial masukin data tanppa looping

# %%
df = pd.read_csv('https://raw.githubusercontent.com/hilmanpr21/CASA0006_DSSS_fiscal-decentralization/main/data/apbd_2021/Kota_Kediri.csv')
df
# Out:
#                                                  akun  anggaran  realisasi  \
# 0                                   Pendapatan Daerah   1225.58    1508.82
# 1                                                 PAD    272.35     439.90
# 2                                        Pajak Daerah    112.89     115.83
# 3                                    Retribusi Daerah     18.92      10.19
# 4            Hasil Pengelolaan Kekayaan Daerah yan...      1.44       0.70
# 5                              Lain-Lain PAD yang Sah    139.10     313.18
# 6                                                TKDD    832.43     912.75
# 7                Pendapatan Transfer Pemerintah Pusat    832.43     912.75
# 8                                  Pendapatan Lainnya    120.80     156.18
# 9                    Pendapatan Transfer Antar Daerah     92.58     127.75
# 10                                   Pendapatan Hibah       NaN        NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   akun        40 non-null     object
#  1   anggaran    24 non-null     float64
#  2   realisasi   24 non-null     float64
#  3   persentase  24 non-null     float64
# dtypes: float64(3), object(1)
# memory usage: 1.4+ KB

# %% [markdown]
# # Masukin Data pake looping

# %%
data = pd.DataFrame()

for i in city_name:
  df = pd.read_csv('https://raw.githubusercontent.com/hilmanpr21/CASA0006_DSSS_fiscal-decentralization/main/data/apbd_2021/'+i+'.csv')
  df = df.drop(columns=['realisasi', 'persentase'])
  df.rename(columns = {'akun':'index'}, inplace = True)
  df.rename(columns = {'anggaran':i}, inplace = True)
  df = df.T
  if len(data) != 0:
    df = df.drop(['index'])
  data = pd.concat([data,df])

data
# Out:
#                                  0        1             2                 3   \
# index             Pendapatan Daerah      PAD  Pajak Daerah  Retribusi Daerah
# Bangkalan                   2223.07   262.47         54.72             22.92
# Banyuwangi                  3036.32   592.74        224.77             72.95
# Batu                         998.77    200.0        149.52             18.16
# Blitar                      2280.05   284.05         90.99             39.39
# Bojonegoro                  3788.74   691.31         99.39             40.25
# Bondowoso                   1999.23   233.31          41.3              28.6
# Gresik                      3271.54   1132.3         724.0            134.29
# Jember                      3708.36   716.85        223.42              42.2
# Jombang                     2609.85   477.85         120.0             15.34
# Kediri                      2777.29   425.69        210.02             26.34
# ...

# %% [markdown]
# # Check Datanya

# %%
data.shape
# Out:
# (39, 40)

# %% [markdown]
# 38 Row padahal ada 37 city, karena row paling yang harusnya jadi header malah di row

# %% [markdown]
# # Ganti Nama kolom data frame

# %%
# Change the column name
data2 = data
data2.columns = data2.iloc[0]
#data.drop(data.index[1])
data2 = data.iloc[1:]

# Clean column names
data2 = data2.rename(columns=lambda x:x.lower().replace(' ','_'))

data2
# Out:
# index            pendapatan_daerah      pad pajak_daerah retribusi_daerah  \
# Bangkalan                  2223.07   262.47        54.72            22.92
# Banyuwangi                 3036.32   592.74       224.77            72.95
# Batu                        998.77    200.0       149.52            18.16
# Blitar                     2280.05   284.05        90.99            39.39
# Bojonegoro                 3788.74   691.31        99.39            40.25
# Bondowoso                  1999.23   233.31         41.3             28.6
# Gresik                     3271.54   1132.3        724.0           134.29
# Jember                     3708.36   716.85       223.42             42.2
# Jombang                    2609.85   477.85        120.0            15.34
# Kediri                     2777.29   425.69       210.02            26.34
# Kota_Blitar                 885.59   187.33        41.06             9.06
# Kota_Kediri                1225.58   272.35       112.89            18.92
# ...

# %% [markdown]
# # Clean Data

# %%
data2.dtypes
# Out:
# index
# pendapatan_daerah                                                                      object
# pad                                                                                    object
# pajak_daerah                                                                           object
# retribusi_daerah                                                                       object
# hasil_pengelolaan_kekayaan_daerah_yang_dipisahkan                                      object
# lain-lain_pad_yang_sah                                                                 object
# tkdd                                                                                   object
# pendapatan_transfer_pemerintah_pusat                                                   object
# pendapatan_lainnya                                                                     object
# pendapatan_transfer_antar_daerah                                                       object
# ...

# %%
data2 = data2.replace(0, np.NaN)
data2
# Out:
# index             pendapatan_daerah      pad  pajak_daerah  retribusi_daerah  \
# Bangkalan                   2223.07   262.47         54.72             22.92
# Banyuwangi                  3036.32   592.74        224.77             72.95
# Batu                         998.77   200.00        149.52             18.16
# Blitar                      2280.05   284.05         90.99             39.39
# Bojonegoro                  3788.74   691.31         99.39             40.25
# Bondowoso                   1999.23   233.31         41.30             28.60
# Gresik                      3271.54  1132.30        724.00            134.29
# Jember                      3708.36   716.85        223.42             42.20
# Jombang                     2609.85   477.85        120.00             15.34
# Kediri                      2777.29   425.69        210.02             26.34
# Kota_Blitar                  885.59   187.33         41.06              9.06
# ...

# %% [markdown]
# # Check Data types

# %%
data2.dtypes
# Out:
# index
# pendapatan_daerah                                                                      float64
# pad                                                                                    float64
# pajak_daerah                                                                           float64
# retribusi_daerah                                                                       float64
# hasil_pengelolaan_kekayaan_daerah_yang_dipisahkan                                      float64
# lain-lain_pad_yang_sah                                                                 float64
# tkdd                                                                                   float64
# pendapatan_transfer_pemerintah_pusat                                                   float64
# pendapatan_lainnya                                                                     float64
# pendapatan_transfer_antar_daerah                                                       float64
# ...

# %% [markdown]
# # Parse datanya  (ini gak perlu)

# %%
cols = data2.columns

cols
# Out:
# Index(['pendapatan_daerah', 'pad', 'pajak_daerah', 'retribusi_daerah',
#        'hasil_pengelolaan_kekayaan_daerah_yang_dipisahkan',
#        'lain-lain_pad_yang_sah', 'tkdd',
#        'pendapatan_transfer_pemerintah_pusat', 'pendapatan_lainnya',
#        'pendapatan_transfer_antar_daerah', 'pendapatan_hibah', 'dana_darurat',
#        'lain-lain_pendapatan_sesuai_dengan_ketentuan_peraturan_perundang-undangan',
#        'belanja_daerah', 'belanja_pegawai', 'belanja_barang_jasa',
#        'belanjaodal', 'belanja_lainnya', 'belanja_bunga', 'belanja_subsidi',
#        'belanja_hibah', 'belanja_bantuan_sosial', 'belanja_tidak_terduga',
#        'belanja_bagi_hasil', 'belanja_bantuan_keuangan', 'surplus/(defisit)',
#        'pembiayaan_daerah', 'penerimaan_pembiayaan_daerah',
#        'sisa_lebih_perhitungan_anggaran_tahun_sebelumnya',
#        'pencairan_dana_cadangan', 'penjualan_kekayaan_daerah_yang_dipisahkan',
#        'penerimaan_pinjaman_daerah',
# ...

# %%
data2[cols] = data2[cols].apply(pd.to_numeric, errors='coerce')
data2.dtypes
# Out:
# city
# pendapatan_daerah                                                                      float64
# pad                                                                                    float64
# pajak_daerah                                                                           float64
# retribusi_daerah                                                                       float64
# hasil_pengelolaan_kekayaan_daerah_yang_dipisahkan                                      float64
# lain-lain_pad_yang_sah                                                                 float64
# tkdd                                                                                   float64
# pendapatan_transfer_pemerintah_pusat                                                   float64
# pendapatan_lainnya                                                                     float64
# pendapatan_transfer_antar_daerah                                                       float64
# ...

# %% [markdown]
# # Reset Index

# %%
data2 = data2.reset_index()
data2
# Out:
# index             index  pendapatan_daerah      pad  pajak_daerah  \
# 0             Bangkalan            2223.07   262.47         54.72
# 1            Banyuwangi            3036.32   592.74        224.77
# 2                  Batu             998.77   200.00        149.52
# 3                Blitar            2280.05   284.05         90.99
# 4            Bojonegoro            3788.74   691.31         99.39
# 5             Bondowoso            1999.23   233.31         41.30
# 6                Gresik            3271.54  1132.30        724.00
# 7                Jember            3708.36   716.85        223.42
# 8               Jombang            2609.85   477.85        120.00
# 9                Kediri            2777.29   425.69        210.02
# 10          Kota_Blitar             885.59   187.33         41.06
# 11          Kota_Kediri            1225.58   272.35        112.89
# 12          Kota_Madiun            1003.82   226.89         76.98
# ...

# %%
data2.rename(columns = {'index':'city'}, inplace = True)
data2
# Out:
# index              city  pendapatan_daerah      pad  pajak_daerah  \
# 0             Bangkalan            2223.07   262.47         54.72
# 1            Banyuwangi            3036.32   592.74        224.77
# 2                  Batu             998.77   200.00        149.52
# 3                Blitar            2280.05   284.05         90.99
# 4            Bojonegoro            3788.74   691.31         99.39
# 5             Bondowoso            1999.23   233.31         41.30
# 6                Gresik            3271.54  1132.30        724.00
# 7                Jember            3708.36   716.85        223.42
# 8               Jombang            2609.85   477.85        120.00
# 9                Kediri            2777.29   425.69        210.02
# 10          Kota_Blitar             885.59   187.33         41.06
# 11          Kota_Kediri            1225.58   272.35        112.89
# 12          Kota_Madiun            1003.82   226.89         76.98
# ...

# %% [markdown]
# # Nyamain nama kolom city

# %%
data2['city'] = data2['city'].str.lower().replace(' ','_')
data2['city'] = data2['city'].str.replace(' ','_')
data2
# Out:
# index              city  pendapatan_daerah      pad  pajak_daerah  \
# 0             bangkalan            2223.07   262.47         54.72
# 1            banyuwangi            3036.32   592.74        224.77
# 2                  batu             998.77   200.00        149.52
# 3                blitar            2280.05   284.05         90.99
# 4            bojonegoro            3788.74   691.31         99.39
# 5             bondowoso            1999.23   233.31         41.30
# 6                gresik            3271.54  1132.30        724.00
# 7                jember            3708.36   716.85        223.42
# 8               jombang            2609.85   477.85        120.00
# 9                kediri            2777.29   425.69        210.02
# 10          kota_blitar             885.59   187.33         41.06
# 11          kota_kediri            1225.58   272.35        112.89
# 12          kota_madiun            1003.82   226.89         76.98
# ...

# %%
data2.dtypes
# Out:
# index
# city                                                                                    object
# pendapatan_daerah                                                                      float64
# pad                                                                                    float64
# pajak_daerah                                                                           float64
# retribusi_daerah                                                                       float64
# hasil_pengelolaan_kekayaan_daerah_yang_dipisahkan                                      float64
# lain-lain_pad_yang_sah                                                                 float64
# tkdd                                                                                   float64
# pendapatan_transfer_pemerintah_pusat                                                   float64
# pendapatan_lainnya                                                                     float64
# ...

# %% [markdown]
# # check Null Value (!!pake grafik - optional)

# %%
data2.count()
# Out:
# index
# city                                                                                   38
# pendapatan_daerah                                                                      38
# pad                                                                                    38
# pajak_daerah                                                                           38
# retribusi_daerah                                                                       38
# hasil_pengelolaan_kekayaan_daerah_yang_dipisahkan                                      38
# lain-lain_pad_yang_sah                                                                 38
# tkdd                                                                                   38
# pendapatan_transfer_pemerintah_pusat                                                   38
# pendapatan_lainnya                                                                     38
# ...

# %% [markdown]
# # Select Variable
# - Revenue
#     - Own-source Revenue (OSR)
#         - Tax Revenue = `pajak_daerah`
#         - Retribution = `retribusi_daerah`
#         - Regionally-owned enterprise = `hasil_pengelolaan_kekayaan_daerah_yang_dipisahkan`
#     - Intergovermental transfer (IGT) = `tkdd`
# - Spending
#     - General Spending = `belanja_daerah`

# %%
data2_selected = data2[['city','pajak_daerah','retribusi_daerah','hasil_pengelolaan_kekayaan_daerah_yang_dipisahkan', 'tkdd','belanja_daerah']]
data2_selected
# Out:
# index              city  pajak_daerah  retribusi_daerah  \
# 0             bangkalan         54.72             22.92
# 1            banyuwangi        224.77             72.95
# 2                  batu        149.52             18.16
# 3                blitar         90.99             39.39
# 4            bojonegoro         99.39             40.25
# 5             bondowoso         41.30             28.60
# 6                gresik        724.00            134.29
# 7                jember        223.42             42.20
# 8               jombang        120.00             15.34
# 9                kediri        210.02             26.34
# 10          kota_blitar         41.06              9.06
# 11          kota_kediri        112.89             18.92
# 12          kota_madiun         76.98             16.73
# 13          kota_malang        629.61             55.23
# 14       kota_mojokerto         48.60             10.16
# 15        kota_pasuruan         35.03              8.38
# ...

# %%
# Rename the dataset to make it understandable
dict = {'pajak_daerah': 'tax_revenue',
        'retribusi_daerah': 'retribution',
        'hasil_pengelolaan_kekayaan_daerah_yang_dipisahkan': 'regionally-owned_enterprise',
        'tkdd': 'intergovernmental_transfer',
        'belanja_daerah': 'capital_expenditure'}
data2_selected = data2_selected.rename(columns = dict)
data2_selected
# Out:
# index              city  tax_revenue  retribution  \
# 0             bangkalan        54.72        22.92
# 1            banyuwangi       224.77        72.95
# 2                  batu       149.52        18.16
# 3                blitar        90.99        39.39
# 4            bojonegoro        99.39        40.25
# 5             bondowoso        41.30        28.60
# 6                gresik       724.00       134.29
# 7                jember       223.42        42.20
# 8               jombang       120.00        15.34
# 9                kediri       210.02        26.34
# 10          kota_blitar        41.06         9.06
# 11          kota_kediri       112.89        18.92
# 12          kota_madiun        76.98        16.73
# 13          kota_malang       629.61        55.23
# 14       kota_mojokerto        48.60        10.16
# 15        kota_pasuruan        35.03         8.38
# 16     kota_probolinggo        56.25        16.63
# 17             lamongan       140.87        16.67
# ...

# %%
data2_selected = data2_selected.rename(columns = {'pajak_daerah': 'tax_revenue'})
data2_selected
# Out:
# index              city  tax_revenue  retribution  \
# 0             bangkalan        54.72        22.92
# 1            banyuwangi       224.77        72.95
# 2                  batu       149.52        18.16
# 3                blitar        90.99        39.39
# 4            bojonegoro        99.39        40.25
# 5             bondowoso        41.30        28.60
# 6                gresik       724.00       134.29
# 7                jember       223.42        42.20
# 8               jombang       120.00        15.34
# 9                kediri       210.02        26.34
# 10          kota_blitar        41.06         9.06
# 11          kota_kediri       112.89        18.92
# 12          kota_madiun        76.98        16.73
# 13          kota_malang       629.61        55.23
# 14       kota_mojokerto        48.60        10.16
# 15        kota_pasuruan        35.03         8.38
# 16     kota_probolinggo        56.25        16.63
# 17             lamongan       140.87        16.67
# ...

# %% [markdown]
# # Load boundaries city in Indonesia

# %% [markdown]
# url = 'https://github.com/hilmanpr21/CASA0006_DSSS_fiscal-decentralization/raw/main/data/city_level_boundaries/gadm41_IDN_city_level.zip'
#
# ! wget $url

# %%
url = 'https://github.com/hilmanpr21/CASA0006_DSSS_fiscal-decentralization/raw/main/data/city_level_boundaries/gadm41_IDN_city.zip'

! wget $url
# Out:
# --2023-04-21 17:25:48--  https://github.com/hilmanpr21/CASA0006_DSSS_fiscal-decentralization/raw/main/data/city_level_boundaries/gadm41_IDN_city.zip
# Resolving github.com (github.com)... 140.82.121.4
# Connecting to github.com (github.com)|140.82.121.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/hilmanpr21/CASA0006_DSSS_fiscal-decentralization/main/data/city_level_boundaries/gadm41_IDN_city.zip [following]
# --2023-04-21 17:25:49--  https://raw.githubusercontent.com/hilmanpr21/CASA0006_DSSS_fiscal-decentralization/main/data/city_level_boundaries/gadm41_IDN_city.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27269954 (26M) [application/zip]
# ...

# %%
gdf = gpd.read_file(f"zip://gadm41_IDN_city.zip!gadm41_IDN_city.shp")
gdf2 = gdf.rename(columns=lambda x:x.lower().replace(' ','_'))
gdf2.head()
# Out:
#        gid_2 gid_0    country    gid_1 name_1 nl_name_1           name_2  \
# 0  IDN.1.2_1   IDN  Indonesia  IDN.1_1   Aceh        NA       Aceh Barat
# 1  IDN.1.1_1   IDN  Indonesia  IDN.1_1   Aceh        NA  Aceh Barat Daya
# 2  IDN.1.3_1   IDN  Indonesia  IDN.1_1   Aceh        NA       Aceh Besar
# 3  IDN.1.4_1   IDN  Indonesia  IDN.1_1   Aceh        NA        Aceh Jaya
# 4  IDN.1.5_1   IDN  Indonesia  IDN.1_1   Aceh        NA     Aceh Selatan
#
#   varname_2 nl_name_2     type_2 engtype_2  cc_2    hasc_2  \
# 0        NA        NA  Kabupaten   Regency  1107  ID.AC.AB
# 1        NA        NA  Kabupaten   Regency  1112  ID.AC.AD
# 2        NA        NA  Kabupaten   Regency  1108  ID.AC.AR
# 3        NA        NA  Kabupaten   Regency  1116  ID.AC.AJ
# 4        NA        NA  Kabupaten   Regency  1103  ID.AC.AS
#
#                                             geometry
# 0  POLYGON ((96.06915 4.19539, 96.06725 4.19651, ...
# 1  MULTIPOLYGON (((96.94196 3.57464, 96.94110 3.5...
# ...

# %%
gdf2.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### geopandas sudah terupload

# %% [markdown]
# ## ganti nama kota jadi lower case

# %%
gdf2['name_2'] = gdf2['name_2'].str.lower().replace(' ','_')
gdf2['name_2'] = gdf2['name_2'].str.replace(' ','_')
gdf2.head()
# Out:
#        gid_2 gid_0    country    gid_1 name_1 nl_name_1           name_2  \
# 0  IDN.1.2_1   IDN  Indonesia  IDN.1_1   Aceh        NA       aceh_barat
# 1  IDN.1.1_1   IDN  Indonesia  IDN.1_1   Aceh        NA  aceh_barat_daya
# 2  IDN.1.3_1   IDN  Indonesia  IDN.1_1   Aceh        NA       aceh_besar
# 3  IDN.1.4_1   IDN  Indonesia  IDN.1_1   Aceh        NA        aceh_jaya
# 4  IDN.1.5_1   IDN  Indonesia  IDN.1_1   Aceh        NA     aceh_selatan
#
#   varname_2 nl_name_2     type_2 engtype_2  cc_2    hasc_2  \
# 0        NA        NA  Kabupaten   Regency  1107  ID.AC.AB
# 1        NA        NA  Kabupaten   Regency  1112  ID.AC.AD
# 2        NA        NA  Kabupaten   Regency  1108  ID.AC.AR
# 3        NA        NA  Kabupaten   Regency  1116  ID.AC.AJ
# 4        NA        NA  Kabupaten   Regency  1103  ID.AC.AS
#
#                                             geometry
# 0  POLYGON ((96.06915 4.19539, 96.06725 4.19651, ...
# 1  MULTIPOLYGON (((96.94196 3.57464, 96.94110 3.5...
# ...

# %% [markdown]
# # Merge data gdf dan df

# %%
data2.dtypes
# Out:
# index
# city                                                                                    object
# pendapatan_daerah                                                                      float64
# pad                                                                                    float64
# pajak_daerah                                                                           float64
# retribusi_daerah                                                                       float64
# hasil_pengelolaan_kekayaan_daerah_yang_dipisahkan                                      float64
# lain-lain_pad_yang_sah                                                                 float64
# tkdd                                                                                   float64
# pendapatan_transfer_pemerintah_pusat                                                   float64
# pendapatan_lainnya                                                                     float64
# ...

# %%
gdf2.dtypes
# Out:
# gid_2          object
# gid_0          object
# country        object
# gid_1          object
# name_1         object
# nl_name_1      object
# name_2         object
# varname_2      object
# nl_name_2      object
# type_2         object
# engtype_2      object
# cc_2           object
# hasc_2         object
# geometry     geometry
# dtype: object

# %%
# Select Necessary Column
gdf2_selected = gdf2[['city','pajak_daerah','retribusi_daerah','hasil_pengelolaan_kekayaan_daerah_yang_dipisahkan', 'tkdd','belanja_daerah']]
gdf2_selected
# Out:
#               name_2                                           geometry
# 0         aceh_barat  POLYGON ((96.06915 4.19539, 96.06725 4.19651, ...
# 1    aceh_barat_daya  MULTIPOLYGON (((96.94196 3.57464, 96.94110 3.5...
# 2         aceh_besar  MULTIPOLYGON (((95.78426 5.24092, 95.78445 5.2...
# 3          aceh_jaya  MULTIPOLYGON (((95.87673 4.36754, 95.87687 4.3...
# 4       aceh_selatan  MULTIPOLYGON (((97.74693 2.44002, 97.74638 2.4...
# ..               ...                                                ...
# 497           bantul  POLYGON ((110.32938 -8.00756, 110.32954 -8.008...
# 498     gunung_kidul  MULTIPOLYGON (((110.60487 -8.14750, 110.60499 ...
# 499  kota_yogyakarta  POLYGON ((110.39351 -7.82868, 110.39330 -7.828...
# 500      kulon_progo  POLYGON ((110.14531 -7.95117, 110.14469 -7.951...
# 501           sleman  POLYGON ((110.29926 -7.82715, 110.29819 -7.827...
#
# [502 rows x 2 columns]

# %%
data3 = pd.merge(gdf2_selected, data2_selected, left_on='name_2', right_on='city', how='inner').reset_index()
#data3 = pd.merge(data2, gdf2, left_on='city', right_on='name_2', how='inner').reset_index()
data3.plot(column='tax_revenue', cmap='plasma', legend=True,)
# Out:
# <AxesSubplot:>

# %%
data3
# Out:
#     index            name_2  \
# 0       0         bangkalan
# 1       1        banyuwangi
# 2       2              batu
# 3       3            blitar
# 4       4        bojonegoro
# 5       5         bondowoso
# 6       6            gresik
# 7       7            jember
# 8       8           jombang
# 9       9            kediri
# 10     10       kota_blitar
# 11     11       kota_kediri
# 12     12       kota_madiun
# 13     13       kota_malang
# 14     14    kota_mojokerto
# 15     15     kota_pasuruan
# 16     16  kota_probolinggo
# 17     17          lamongan
# 18     18          lumajang
# 19     19            madiun
# 20     20           magetan
# 21     21            malang
# 22     22         mojokerto
# 23     23           nganjuk
# 24     24             ngawi
# 25     25           pacitan
# 26     26         pamekasan
# 27     27          pasuruan
# 28     28          ponorogo
# 29     29       probolinggo
# 30     30           sampang
# 31     31          sidoarjo
# ...

# %%
f = plt.figure()
f.set_size_inches(12,7)

ax1 = f.add_subplot()
data3.plot(column='pad', 
           legend=True, 
           legend_kwds={'label': "PAD",
                        'orientation': "vertical"},
           figsize=(12,6), 
           ax=ax1)

f.subplots_adjust(top=0.92)
f.suptitle(f"PAD", x=0.025, size=24,);
#plt.savefig('pad.png', dpi=150)

# %% [markdown]
# # Cek Distribution

# %%
data3.columns
# Out:
# Index(['index', 'name_2', 'geometry', 'city', 'tax_revenue', 'retribution',
#        'regionally-owned_enterprise', 'intergovernmental_transfer',
#        'capital_expenditure'],
#       dtype='object')

# %%
ax = data3.plot(x="city", 
                y=["tax_revenue", "retribution", "regionally-owned_enterprise", "intergovernmental_transfer", "capital_expenditure"], 
                kind="bar", 
                rot=0,
                #stacked=True,
                figsize=(25,15),
                width=0.8,
                fontsize=14,
                title="Revenue Expenditure Distribution"
               )
_ = ax.set_xticklabels(ax.get_xticklabels(), rotation=60)
_ = ax.legend(loc='upper left', fontsize=12)

# %%
data3.plot(x="city", 
                y="pajak_daerah", 
                kind="bar",
          fontsize=12)
data3.plot(x="city", 
                y="retribusi_daerah", 
                kind="bar",
          fontsize=12)
data3.plot(x="city", 
                y="hasil_pengelolaan_kekayaan_daerah_yang_dipisahkan", 
                kind="bar",
          fontsize=12)
data3.plot(x="city", 
                y="tkdd", 
                kind="bar",
          fontsize=12)
_ = ax.legend(loc='upper left', fontsize=12)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'pajak_daerah'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# # Selected Varible
# - Revenue
#
#     - Own-source Revenue (OSR)
#         - Tax Revenue = `pajak_daerah`
#         - Retribution = `retribusi_daerah`
#         - Regionally-owned enterprise = `hasil_pengelolaan_kekayaan_daerah_yang_dipisahkan`
#     - Intergovermental transfer (IGT) = `tkdd`
# - Spending
#     - General Spending = `belanja_daerah`

# %%
data3_check = data3[['tax_revenue','retribution','regionally-owned_enterprise', 'intergovernmental_transfer','capital_expenditure']]
data3_check
# Out:
#     tax_revenue  retribution  regionally-owned_enterprise  \
# 0         54.72        22.92                         4.40
# 1        224.77        72.95                        24.38
# 2        149.52        18.16                         4.23
# 3         90.99        39.39                         2.18
# 4         99.39        40.25                       144.61
# 5         41.30        28.60                         4.20
# 6        724.00       134.29                        14.01
# 7        223.42        42.20                         6.10
# 8        120.00        15.34                         3.43
# 9        210.02        26.34                         8.92
# 10        41.06         9.06                         1.10
# 11       112.89        18.92                         1.44
# 12        76.98        16.73                        15.09
# 13       629.61        55.23                        25.22
# 14        48.60        10.16                         4.82
# ...

# %%
data3_check_hist = data3_check.hist(figsize = (19,15))
plt.rc('font', size=9)

# %%
#sns.set(font_scale=2)
data3_plot_sns = sns.pairplot(data3_check, height=4)
sns.set(font_scale=1.25)
plt.show()

# %% [markdown]
# # Clustering

# %% [markdown]
# ## Make function
# funtion for plotting the the clustering into the maps

# %%
def mapping_clusters(labels_cluster):
    data3['cluster_nm'] = labels_cluster
    data3.plot(column='cluster_nm', categorical=True, legend=True, figsize=(12,8), cmap='Paired');

# %% [markdown]
# function for centroid plot

# %%
# adapted from this tutorial: https://towardsdatascience.com/how-to-make-stunning-radar-charts-with-python-implemented-in-matplotlib-and-plotly-91e21801d8ca
def radar_plot_cluster_centroids(df_cluster_centroid):
    # parameters
    # df_cluster_centroid: a dataframe with rows representing a cluster centroid and columns representing variables
    
    # add an additional element to both categories and restaurants that’s identical to the first item
    # manually 'close' the line
    categories = df_cluster_centroid.columns.values.tolist()
    categories = [*categories, categories[0]]
    
    label_loc = np.linspace(start=0, stop=2 * np.pi, num=len(categories))
    
    plt.figure(figsize=(12, 8))
    plt.subplot(polar=True)
    for index, row in df_cluster_centroid.iterrows():
        centroid = row.tolist()
        centroid = [*centroid, centroid[0]]
        label = "Cluster {}".format(index)
        plt.plot(label_loc, centroid, label=label)
    plt.title('Cluster centroid comparison', size=20, y=1.05)
    lines, labels = plt.thetagrids(np.degrees(label_loc), labels=categories)
    plt.legend()
    plt.show()

# %% [markdown]
# # DBSCAN
# - we use DBSCAn because it's sensitive to outliers

# %%
# extract necessary data first
raw = data2_selected.set_index('city').copy()
raw.head()
# Out:
# index       tax_revenue  retribution  regionally-owned_enterprise  \
# city
# bangkalan         54.72        22.92                         4.40
# banyuwangi       224.77        72.95                        24.38
# batu             149.52        18.16                         4.23
# blitar            90.99        39.39                         2.18
# bojonegoro        99.39        40.25                       144.61
#
# index       intergovernmental_transfer  capital_expenditure
# city
# bangkalan                      1734.28              2287.33
# banyuwangi                     2200.95              3216.20
# batu                            689.97              1087.36
# blitar                         1766.78              2314.92
# bojonegoro                     2894.85              6219.91

# %%
rs = RobustScaler(quantile_range=(10.0, 90.0))

normed = raw.copy()
for c in raw.columns.values:
    normed[c] = rs.fit_transform(raw[c].values.reshape(-1,1))
    print("The range of {} is [{}, {}]".format(c, normed[c].min(), normed[c].max()))
normed.head()
# Out:
# The range of tax_revenue is [-0.12023745639924849, 9.738652624988799]
# The range of retribution is [-0.32749354907552874, 5.963952428069757]
# The range of regionally-owned_enterprise is [-0.17414303851036816, 7.063267033432078]
# The range of intergovernmental_transfer is [-0.7280427059418401, 0.7999541889395994]
# The range of capital_expenditure is [-0.420449640836312, 2.3114956717671795]
# index       tax_revenue  retribution  regionally-owned_enterprise  \
# city
# bangkalan     -0.073216    -0.033176                    -0.031951
# banyuwangi     0.307005     0.937470                     0.813584
# batu           0.138751    -0.125526                    -0.039145
# blitar         0.007882     0.286363                    -0.125899
# bojonegoro     0.026664     0.303048                     5.901608
#
# index       intergovernmental_transfer  capital_expenditure
# city
# bangkalan                     0.033860            -0.011680
# ...

# %%
normed_copy = normed.copy()

# %%
neighbors = NearestNeighbors(n_neighbors=20)
neighbors_fit = neighbors.fit(raw)
distances, indices = neighbors_fit.kneighbors(raw)

# %%
distances = np.sort(distances, axis=0)
distances = distances[:,1]
plt.plot(distances)

# %%
minPts = 8 # we set minPts as normed.shape[1] + 1 
epsilon = 500
dbsc = DBSCAN(eps=epsilon, min_samples=minPts)
dbsc.fit(raw)

# We now have our DBSCAN object created, and we can extract the groups it has identified. We do this using the `.labels_` method.
cluster_nm = dbsc.labels_

df_dbscan = raw.copy()
df_dbscan["dbscan_labels"] = dbsc.labels_

mapping_clusters(cluster_nm)

# %%
pd.Series(dbsc.labels_).value_counts()
# Out:
# -1    33
#  0     5
# dtype: int64

# %%
df_dbscan = normed.copy()
df_dbscan['cluster'] = dbsc.labels_
df_dbscan_centroid = df_dbscan.groupby('cluster').mean()
# drop the outlier
df_dbscan_centroid.drop(-1, inplace=True)
# df_dbscan_centroid.reset_index()
radar_plot_cluster_centroids(df_dbscan_centroid)

# %%
metrics.silhouette_score(normed, dbsc.labels_)
# Out:
# -0.331039513161892

# %% [markdown]
# # k-means

# %%
# calculate SSE for a range of number of cluster
list_SSE = []
min_k = 1
max_k = 10
range_k = range(min_k, max_k+1)
for i in range_k:
    km = KMeans(
        n_clusters=i, init='random',
        n_init=10, max_iter=300,
        tol=1e-04, random_state=0
    )
    km.fit(normed)
    # inertia is a concept from physics. Roughly it means SSE of clustering.
    list_SSE.append(km.inertia_)

# plot
plt.plot(range_k, list_SSE, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('SSE')
plt.show()

# %%
k_cluster = 4
random_seed = 100
kmeans_method = KMeans(n_clusters=k_cluster,random_state=random_seed)
x_transformed = kmeans_method.fit_transform(normed)
print(normed.shape)
print(normed.columns)
# print(kmeans_method.labels_)
print(x_transformed.shape)

for centroid in kmeans_method.cluster_centers_:
    print(np.linalg.norm(np.array(normed)[0] - centroid))
print(x_transformed[0])
# Out:
# (38, 5)
# Index(['tax_revenue', 'retribution', 'regionally-owned_enterprise',
#        'intergovernmental_transfer', 'capital_expenditure'],
#       dtype='object', name='index')
# (38, 4)
# 0.2562519720313452
# 13.71227576471829
# 6.114311436723904
# 1.4871736351555094
# [ 0.25625197 13.71227576  6.11431144  1.48717364]

# %%
k_cluster = 3
random_seed = 123
kmeans_method = KMeans(n_clusters=k_cluster,random_state=random_seed)
kmeans_method.fit(ready_df)

# plotting
mapping_clusters(kmeans_method.labels_)

# %%
df_kmeans = normed.copy()
df_kmeans["kmeans_labels"] = kmeans_method.labels_
df_kmeans
# Out:
# index             tax_revenue  retribution  regionally-owned_enterprise  \
# city
# bangkalan           -0.073216    -0.033176                    -0.031951
# banyuwangi           0.307005     0.937470                     0.813584
# batu                 0.138751    -0.125526                    -0.039145
# blitar               0.007882     0.286363                    -0.125899
# bojonegoro           0.026664     0.303048                     5.901608
# bondowoso           -0.103222     0.077023                    -0.040415
# gresik               1.423251     2.127544                     0.374736
# jember               0.303987     0.340880                     0.039992
# jombang              0.072746    -0.180238                    -0.073000
# kediri               0.274025     0.033176                     0.159331
# kota_blitar         -0.103759    -0.302078                    -0.171604
# kota_kediri          0.056849    -0.110781                    -0.157215
# ...

# %% [markdown]
# # Max-p Clustering

# %%
plt.rcParams["figure.figsize"] = [12, 8]
warnings.filterwarnings("ignore")

RANDOM_SEED = 10000

# %%
attrs_name = normed.columns.values.tolist()
attrs_name
# Out:
# ['tax_revenue',
#  'retribution',
#  'regionally-owned_enterprise',
#  'intergovernmental_transfer',
#  'capital_expenditure']

# %%
w = libpysal.weights.Queen.from_dataframe(data3)
w

# %%
threshold = 0.2 * normed.shape[0]
print(threshold)
normed_copy = normed.copy()
normed_copy["count"] = 1
threshold_name = "count"
# Out:
# 7.6000000000000005

# %%
# %%time
np.random.seed(RANDOM_SEED)
model = MaxP(normed_copy, w, attrs_name, threshold_name, threshold, top_n=3)
model.solve()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# File <timed exec>:3, in <module>
#
# File /opt/conda/lib/python3.10/site-packages/spopt/region/maxp.py:804, in MaxPHeuristic.solve(self)
#     802 def solve(self):
#     803     """Solve a max-p-regions problem and get back the results."""
# --> 804     max_p, label = maxp(
#     805         self.gdf,
#     806         self.w,
#     807         self.attrs_name,
#     808         self.threshold_name,
#     809         self.threshold,
#     810         self.top_n,
#     811         self.max_iterations_construction,
#     812         self.max_iterations_sa,
#     813         verbose=self.verbose,
#     814         policy=self.policy,
#     815     )
#     816     self.labels_ = label
#     817     self.p = max_p
#
# ...

# %% [markdown]
# # Visualizing the cluster

# %%
def f_cluster_visualise(p_labelled_df,p_vis_rows,p_log_columns,p_log = False):
    
     # Rules
    columns_to_log = p_log_columns
    log = p_log
    df_kmeans = p_labelled_df.copy()

    # Visualise
    plots_total_number = df_kmeans.shape[1]
    plots_per_row = p_vis_rows
    plots_per_column = math.ceil(plots_total_number/plots_per_row)

    plots_row_coordinates = list(np.arange(0,plots_per_row,1)) * plots_per_column
    plots_row_coordinates = plots_row_coordinates[:plots_total_number]

    plots_column_coordinates = sorted(list(np.arange(0,plots_per_column,1)) * plots_per_row)

    fig, axes = plt.subplots(plots_per_row,plots_per_column,figsize = (16,6))

    for index,column in enumerate(list(df_kmeans.columns)):

        ax_assign = axes[plots_row_coordinates[index]][plots_column_coordinates[index]]

        for value in list(df_kmeans.kmeans_labels.unique()):

            if log is True:

                if column in columns_to_log:
                    # split dataframe into the number of clusters and visualise
                    df1 = df_kmeans[df_kmeans.kmeans_labels == value]
                    np.log(df1[column]).hist(ax = ax_assign, alpha = 0.3,label = f"Cluster {value}")
                    ax_assign.title.set_text(f"{column} (log)")
                    ax_assign.legend()

                else:
                    df1 = df_kmeans[df_kmeans.kmeans_labels == value]
                    df1[column].hist(ax = ax_assign, alpha = 0.3,label = f"Cluster {value}")
                    ax_assign.title.set_text(column)
                    ax_assign.legend()
            else:
                df1 = df_kmeans[df_kmeans.kmeans_labels == value]
                df1[column].hist(ax = ax_assign, alpha = 0.3,label = f"Cluster {value}")
                ax_assign.title.set_text(column)
                ax_assign.legend(loc = "upper right")

    plt.tight_layout()

# %%
def f_cluster_summarise(p_labelled_df):
    
    summary_list = []
    
    for value in list(p_labelled_df.kmeans_labels.unique()):

        # split dataframe into the number of clusters to summarise
        df1 = p_labelled_df[p_labelled_df.kmeans_labels == value]
        df1_summary = df1.describe()
        
        summary_list.append(df1_summary)
        
    return summary_list

# %%
columns_to_log = ["tax_revenue","retribution"]
f_cluster_visualise(df_kmeans,2,columns_to_log,p_log = True)
kmeans_summaries = f_cluster_summarise(df_kmeans)
